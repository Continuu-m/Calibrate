# %%
from src.api.tasks import detect_subtasks
test_tasks = ["Build ML model", "Write report", "Calibrate patterns"]

results = [detect_subtasks(t) for t in test_tasks]
subtask_counts = [len(r) for r in results]

print("Week 1 PRD Results:")
for task, count in zip(test_tasks, subtask_counts):
    print(f"  {task}: {count} subtasks {'✅' if count >= 3 else '❌'}")

accuracy = sum(c >= 3 for c in subtask_counts) / len(subtask_counts)
print(f"\n✅ Accuracy: {accuracy:.0%} (target 80%)")
print("Demo traces logged to notebook!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from src.api.tasks import detect_subtasks
#       2 test_tasks = ["Build ML model", "Write report", "Calibrate patterns"]
#       4 results = [detect_subtasks(t) for t in test_tasks]
#
# ModuleNotFoundError: No module named 'src'
